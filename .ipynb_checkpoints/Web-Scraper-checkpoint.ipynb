# %%
# Loading requisite libraries
import selenium
from selenium.common.exceptions import NoSuchElementException, ElementClickInterceptedException
from selenium import webdriver
import time
import pandas as pd
import os

# %%
# List the path to chromedri
path = "<Path to the chromedriver>"
        
#Initializing the webdriver
options = webdriver.ChromeOptions()
     
#Change the path to where chromedriver is in your home folder.
driver = webdriver.Chrome(executable_path=path, options=options)
driver.set_window_size(1120, 1000)

url = 'https://www.glassdoor.com/Job/jobs.htm?sc.keyword="' + "Data-Scientist" + '"&locT=C&locId=1147401&locKeyword=san+fransico,%20CA&jobType=all&fromAge=-1&minSalary=0&includeNoSalaryJobs=true&radius=100&cityId=-1&minRating=0.0&industryId=-1&sgocId=-1&seniorityType=all&companyId=-1&employerSizes=0&applicationType=0&remoteWorkType=0'
driver.get(url)
jobs = []

try:
    driver.find_element_by_css_selector('[data-test="detailSalary"]').click()
except ElementClickInterceptedException:
    pass
time.sleep(.1)

try:
    driver.find_element_by_css_selector('[alt="Close"]').click()
except NoSuchElementException:
    pass
time.sleep(.1)

job_buttons = driver.find_elements_by_css_selector("li.react-job-listing")
df = pd.DataFrame()
# Out:
# <ipython-input-190-fd12c7de9d8f>:10: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(executable_path=path, options=options)
# <ipython-input-190-fd12c7de9d8f>:18: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_css_selector('[data-test="detailSalary"]').click()
# <ipython-input-190-fd12c7de9d8f>:24: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_css_selector('[alt="Close"]').click()
# <ipython-input-190-fd12c7de9d8f>:29: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   job_buttons = driver.find_elements_by_css_selector("li.react-job-listing")

# %%
def parse_site():
    job_buttons = driver.find_elements_by_css_selector("li.react-job-listing")
    x=1
    jobs.clear()
    for job_button in job_buttons: 
        try:
            company_name = driver.find_element_by_xpath('//*[@id="MainCol"]/div[1]/ul/li['+str(x)+']/div[2]/div[1]/a').text
            location = driver.find_element_by_xpath('//*[@id="MainCol"]/div[1]/ul/li['+str(x)+']/div[2]/div[2]/span').text
            job_title = driver.find_element_by_xpath('//*[@id="MainCol"]/div[1]/ul/li['+str(x)+']/div[2]/a/span').text        
        except:
            time.sleep(5)

        try:
            rating = driver.find_element_by_xpath('//*[@id="MainCol"]/div[1]/ul/li['+str(x)+']/div[1]/span').text
        except NoSuchElementException:
            rating = -1

        try:
            salary_est = driver.find_element_by_xpath('//*[@id="MainCol"]/div[1]/ul/li['+str(x)+']/div[2]/div[3]/div[1]/span').text
        except NoSuchElementException:
            salary_est = -1

        job_button.click()
        time.sleep(15)

        try:
            founded = driver.find_element_by_xpath('//*[@id="EmpBasicInfo"]/div[1]/div/div[2]/span[2]').text
        except NoSuchElementException:
            founded = -1

        try:
            size = driver.find_element_by_xpath('//*[@id="EmpBasicInfo"]/div[1]/div/div[1]/span[2]').text
        except NoSuchElementException:
            size = -1

        try:
            sector = driver.find_element_by_xpath('//*[@id="EmpBasicInfo"]/div[1]/div/div[5]/span[2]').text
        except NoSuchElementException:
            sector = -1

        try:
            revenue = driver.find_element_by_xpath('//*[@id="EmpBasicInfo"]/div[1]/div/div[6]/span[2]').text
        except NoSuchElementException:
            revenue = -1

        try:
            industry = driver.find_element_by_xpath('//*[@id="EmpBasicInfo"]/div[1]/div/div[4]/span[2]').text
        except NoSuchElementException:
            industry = -1

        try:
            type_of_ownership = driver.find_element_by_xpath('//*[@id="EmpBasicInfo"]/div[1]/div/div[3]/span[2]').text
        except NoSuchElementException:
            type_of_ownership = -1 

        jobs.append({"Job Title" : job_title,
                     "Company Name" : company_name,
                     "Salary Estimate" : salary_est,
                     "Rating" : rating,
                     "Location" : location,
                     "Founded In": founded,
                     "Company Size": size,
                     "Sector": sector,
                     "Revenue": revenue,
                     "Industry": industry,
                     "Ownership_type": type_of_ownership
                    })

        print(company_name +" I "+location+" I "+job_title)
        print(x)
        x += 1
 
    return pd.DataFrame(jobs)

# %%
x=1
while (x<21):
    temp = parse_site()
    df = df.append(temp, ignore_index=True)
    try:
        driver.find_element_by_xpath('//*[@id="FooterPageNav"]/div/ul/li[7]/a/span').click()
        x += 1
    except:
        x = 21
    time.sleep(15)

df
#print(founded + size+sector+revenue+industry+type_of_ownership)
# Out:
# <ipython-input-191-9792f3e41f94>:2: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   job_buttons = driver.find_elements_by_css_selector("li.react-job-listing")
# <ipython-input-191-9792f3e41f94>:7: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   company_name = driver.find_element_by_xpath('//*[@id="MainCol"]/div[1]/ul/li['+str(x)+']/div[2]/div[1]/a').text
# <ipython-input-191-9792f3e41f94>:8: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   location = driver.find_element_by_xpath('//*[@id="MainCol"]/div[1]/ul/li['+str(x)+']/div[2]/div[2]/span').text
# <ipython-input-191-9792f3e41f94>:9: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   job_title = driver.find_element_by_xpath('//*[@id="MainCol"]/div[1]/ul/li['+str(x)+']/div[2]/a/span').text
# <ipython-input-191-9792f3e41f94>:14: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   rating = driver.find_element_by_xpath('//*[@id="MainCol"]/div[1]/ul/li['+str(x)+']/div[1]/span').text
# <ipython-input-191-9792f3e41f94>:19: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   salary_est = driver.find_element_by_xpath('//*[@id="MainCol"]/div[1]/ul/li['+str(x)+']/div[2]/div[3]/div[1]/span').text
# <ipython-input-191-9792f3e41f94>:27: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   founded = driver.find_element_by_xpath('//*[@id="EmpBasicInfo"]/div[1]/div/div[2]/span[2]').text
# <ipython-input-191-9792f3e41f94>:32: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   size = driver.find_element_by_xpath('//*[@id="EmpBasicInfo"]/div[1]/div/div[1]/span[2]').text
# <ipython-input-191-9792f3e41f94>:37: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   sector = driver.find_element_by_xpath('//*[@id="EmpBasicInfo"]/div[1]/div/div[5]/span[2]').text
# <ipython-input-191-9792f3e41f94>:42: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   revenue = driver.find_element_by_xpath('//*[@id="EmpBasicInfo"]/div[1]/div/div[6]/span[2]').text
# <ipython-input-191-9792f3e41f94>:47: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   industry = driver.find_element_by_xpath('//*[@id="EmpBasicInfo"]/div[1]/div/div[4]/span[2]').text
# <ipython-input-191-9792f3e41f94>:52: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-192-e0785bdfcc78> in <module>
#       1 x=1
#       2 while (x<21):
# ----> 3     temp = parse_site()
#       4     df = df.append(temp, ignore_index=True)
#       5     try:
#
# <ipython-input-191-9792f3e41f94> in parse_site()
#      22
#      23         job_button.click()
# ---> 24         time.sleep(15)
#      25
#      26         try:
#
# KeyboardInterrupt:

# %%
path = os.path.join(os.getcwd(),'glassdoor_job_postings.xls')
df.to_excel(path, index=False)

# %%
df
# Out:
#                                              Job Title  \
# 0     Ticket/Gate Agent (Customer Service Agent) - SFO
# 1                               Patient Care Assistant
# 2     Front Desk Receptionist/Administrative Assistant
# 3                        Program Associate, Google.org
# 4
# ..                                                 ...
# 265                                     Data Scientist
# 266                                     Data Scientist
# 267  Senior Data Scientist - Consumer Decision Science
# 268          Sr. Data Scientist, Quantitative Research
# 269            Data Scientist (Telemedicine Analytics)
#
#                                Company Name  \
# 0                                     Delta
# 1    University of California San Francisco
# 2               Preston Wood Pediatrics LLC
# 3                                    Google
# 4    University of California San Francisco
# ..                                      ...
# 265                   FriendFinder Networks
# 266  University of California San Francisco
# 267                               Glassdoor
# 268                                    Wish
# 269                                 Forward
#
#                        Salary Estimate Rating           Location Founded In  \
# 0                                   -1    4.4  San Francisco, CA       1928
# 1         $33K - $61K (Glassdoor est.)    4.1  San Francisco, CA       1864
# 2    $29 - $34 Per Hour(Employer est.)     -1  San Francisco, CA         -1
# 3        $75K - $175K (Glassdoor est.)    4.5  San Francisco, CA       1998
# 4         $34K - $62K (Glassdoor est.)    4.1  San Francisco, CA       1864
# ..                                 ...    ...                ...        ...
# 265      $97K - $175K (Glassdoor est.)    2.9  San Francisco, CA         -1
# 266      $78K - $156K (Glassdoor est.)    4.1  San Francisco, CA         -1
# 267      $136K - $170K (Employer est.)    4.0  San Francisco, CA         -1
# 268     $109K - $214K (Glassdoor est.)    3.6  San Francisco, CA         -1
# 269      $84K - $164K (Glassdoor est.)    4.0  San Francisco, CA         -1
#
#          Company Size                  Sector                   Revenue  \
# 0    10000+ Employees        Travel & Tourism        $10+ billion (USD)
# 1    10000+ Employees               Education  $25 to $50 million (USD)
# 2                  -1                      -1                        -1
# 3    10000+ Employees  Information Technology        $10+ billion (USD)
# 4    10000+ Employees               Education  $25 to $50 million (USD)
# ..                ...                     ...                       ...
# 265                -1                      -1                        -1
# 266                -1                      -1                        -1
# 267                -1                      -1                        -1
# 268                -1                      -1                        -1
# 269                -1                      -1                        -1
#
#                     Industry        Ownership_type
# 0                   Airlines      Company - Public
# 1    Colleges & Universities  College / University
# 2                         -1                    -1
# 3                   Internet      Company - Public
# 4    Colleges & Universities  College / University
# ..                       ...                   ...
# 265                       -1                    -1
# 266                       -1                    -1
# 267                       -1                    -1
# 268                       -1                    -1
# 269                       -1                    -1
#
# [270 rows x 11 columns]
